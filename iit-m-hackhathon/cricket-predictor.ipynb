# %%
import pandas as pd

dataset = pd.read_csv("./dataset/all_matches.csv")
# Out:
# C:\Users\praghuvanshi\AppData\Roaming\Python\Python39\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
dataset
# Out:
#         match_id   season start_date  \
# 0         335982  2007/08  4/18/2008
# 1         335982  2007/08  4/18/2008
# 2         335982  2007/08  4/18/2008
# 3         335982  2007/08  4/18/2008
# 4         335982  2007/08  4/18/2008
# ...          ...      ...        ...
# 194349   1254060     2021  4/11/2021
# 194350   1254060     2021  4/11/2021
# 194351   1254060     2021  4/11/2021
# 194352   1254060     2021  4/11/2021
# 194353   1254060     2021  4/11/2021
#
#                                            venue  innings  ball  \
# 0                          M Chinnaswamy Stadium        1   0.1
# 1                          M Chinnaswamy Stadium        1   0.2
# 2                          M Chinnaswamy Stadium        1   0.3
# 3                          M Chinnaswamy Stadium        1   0.4
# 4                          M Chinnaswamy Stadium        1   0.5
# ...                                          ...      ...   ...
# ...

# %%
dataset = dataset[dataset["ball"] < 6.1]

# %%
dataset
# Out:
#         match_id   season start_date  \
# 0         335982  2007/08  4/18/2008
# 1         335982  2007/08  4/18/2008
# 2         335982  2007/08  4/18/2008
# 3         335982  2007/08  4/18/2008
# 4         335982  2007/08  4/18/2008
# ...          ...      ...        ...
# 194260   1254060     2021  4/11/2021
# 194261   1254060     2021  4/11/2021
# 194262   1254060     2021  4/11/2021
# 194263   1254060     2021  4/11/2021
# 194264   1254060     2021  4/11/2021
#
#                                            venue  innings  ball  \
# 0                          M Chinnaswamy Stadium        1   0.1
# 1                          M Chinnaswamy Stadium        1   0.2
# 2                          M Chinnaswamy Stadium        1   0.3
# 3                          M Chinnaswamy Stadium        1   0.4
# 4                          M Chinnaswamy Stadium        1   0.5
# ...                                          ...      ...   ...
# ...

# %%
dataset.head(40)
# Out:
#      match_id   season start_date                  venue  innings  ball  \
# 0      335982  2007/08  4/18/2008  M Chinnaswamy Stadium        1   0.1
# 1      335982  2007/08  4/18/2008  M Chinnaswamy Stadium        1   0.2
# 2      335982  2007/08  4/18/2008  M Chinnaswamy Stadium        1   0.3
# 3      335982  2007/08  4/18/2008  M Chinnaswamy Stadium        1   0.4
# 4      335982  2007/08  4/18/2008  M Chinnaswamy Stadium        1   0.5
# 5      335982  2007/08  4/18/2008  M Chinnaswamy Stadium        1   0.6
# 6      335982  2007/08  4/18/2008  M Chinnaswamy Stadium        1   0.7
# 7      335982  2007/08  4/18/2008  M Chinnaswamy Stadium        1   1.1
# 8      335982  2007/08  4/18/2008  M Chinnaswamy Stadium        1   1.2
# 9      335982  2007/08  4/18/2008  M Chinnaswamy Stadium        1   1.3
# 10     335982  2007/08  4/18/2008  M Chinnaswamy Stadium        1   1.4
# 11     335982  2007/08  4/18/2008  M Chinnaswamy Stadium        1   1.5
# ...

# %%
dataset['ball_runs'] = dataset['runs_off_bat'] + dataset['extras']
# Out:
# <ipython-input-15-5f5b6e511765>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['ball_runs'] = dataset['runs_off_bat'] + dataset['extras']

# %%
dataset
# Out:
#         match_id   season start_date  \
# 0         335982  2007/08  4/18/2008
# 1         335982  2007/08  4/18/2008
# 2         335982  2007/08  4/18/2008
# 3         335982  2007/08  4/18/2008
# 4         335982  2007/08  4/18/2008
# ...          ...      ...        ...
# 194260   1254060     2021  4/11/2021
# 194261   1254060     2021  4/11/2021
# 194262   1254060     2021  4/11/2021
# 194263   1254060     2021  4/11/2021
# 194264   1254060     2021  4/11/2021
#
#                                            venue  innings  ball  \
# 0                          M Chinnaswamy Stadium        1   0.1
# 1                          M Chinnaswamy Stadium        1   0.2
# 2                          M Chinnaswamy Stadium        1   0.3
# 3                          M Chinnaswamy Stadium        1   0.4
# 4                          M Chinnaswamy Stadium        1   0.5
# ...                                          ...      ...   ...
# ...

# %%
dataset['total_runs'] = dataset['ball_runs']
